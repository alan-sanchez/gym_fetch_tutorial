# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
# !pip3 install stable-baselines3[extra]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3[extra] in /home/strider/.local/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (1.26.0)
# Requirement already satisfied: torch>=1.13 in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: cloudpickle in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: opencv-python in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.8.0.76)
# Requirement already satisfied: pygame in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.14.0)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.66.1)
# Requirement already satisfied: rich in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (13.5.3)
# Requirement already satisfied: shimmy[atari]~=1.1.0 in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: pillow in /usr/lib/python3/dist-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in /home/strider/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (8.0.3)
# Requirement already satisfied: requests in /home/strider/.local/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in /home/strider/.local/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: ale-py~=0.8.1 in /home/strider/.local/lib/python3.10/site-packages (from shimmy[atari]~=1.1.0->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /home/strider/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/strider/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.58.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/strider/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/strider/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/strider/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in /home/strider/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.24.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/strider/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (68.1.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/strider/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/strider/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: filelock in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.12.4)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.9)
# Requirement already satisfied: networkx in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/strider/.local/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: cmake in /home/strider/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.13->stable-baselines3[extra]) (3.27.5)
# Requirement already satisfied: lit in /home/strider/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.13->stable-baselines3[extra]) (16.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/strider/.local/lib/python3.10/site-packages (from pandas->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->stable-baselines3[extra]) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/strider/.local/lib/python3.10/site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/strider/.local/lib/python3.10/site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/strider/.local/lib/python3.10/site-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: importlib-resources in /home/strider/.local/lib/python3.10/site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0->stable-baselines3[extra]) (6.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/strider/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/strider/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/strider/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: urllib3<2.0 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.26.5)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/strider/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /home/strider/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/strider/.local/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2020.6.20)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/strider/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/lib/python3/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install gymnasium
# !pip install gymnasium-robotics
# !pip install gymnasium-robotics[mujoco-py]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium in /home/strider/.local/lib/python3.10/site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium) (1.26.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium) (0.0.4)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium-robotics in /home/strider/.local/lib/python3.10/site-packages (1.2.3)
# Requirement already satisfied: mujoco>=2.3.3 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics) (2.3.7)
# Requirement already satisfied: numpy>=1.21.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics) (1.26.0)
# Requirement already satisfied: gymnasium>=0.26 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics) (0.29.1)
# Requirement already satisfied: PettingZoo>=1.23.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics) (1.24.1)
# Requirement already satisfied: Jinja2>=3.0.3 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics) (3.1.2)
# Requirement already satisfied: imageio in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics) (2.31.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium>=0.26->gymnasium-robotics) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium>=0.26->gymnasium-robotics) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium>=0.26->gymnasium-robotics) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/strider/.local/lib/python3.10/site-packages (from Jinja2>=3.0.3->gymnasium-robotics) (2.1.3)
# Requirement already satisfied: absl-py in /home/strider/.local/lib/python3.10/site-packages (from mujoco>=2.3.3->gymnasium-robotics) (2.0.0)
# Requirement already satisfied: glfw in /home/strider/.local/lib/python3.10/site-packages (from mujoco>=2.3.3->gymnasium-robotics) (2.6.2)
# Requirement already satisfied: pyopengl in /usr/lib/python3/dist-packages (from mujoco>=2.3.3->gymnasium-robotics) (3.1.5)
# Requirement already satisfied: pillow>=8.3.2 in /usr/lib/python3/dist-packages (from imageio->gymnasium-robotics) (9.0.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium-robotics[mujoco-py] in /home/strider/.local/lib/python3.10/site-packages (1.2.3)
# WARNING: gymnasium-robotics 1.2.3 does not provide the extra 'mujoco-py'
# Requirement already satisfied: mujoco>=2.3.3 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics[mujoco-py]) (2.3.7)
# Requirement already satisfied: numpy>=1.21.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics[mujoco-py]) (1.26.0)
# Requirement already satisfied: gymnasium>=0.26 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics[mujoco-py]) (0.29.1)
# Requirement already satisfied: PettingZoo>=1.23.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics[mujoco-py]) (1.24.1)
# Requirement already satisfied: Jinja2>=3.0.3 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics[mujoco-py]) (3.1.2)
# Requirement already satisfied: imageio in /home/strider/.local/lib/python3.10/site-packages (from gymnasium-robotics[mujoco-py]) (2.31.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium>=0.26->gymnasium-robotics[mujoco-py]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium>=0.26->gymnasium-robotics[mujoco-py]) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/strider/.local/lib/python3.10/site-packages (from gymnasium>=0.26->gymnasium-robotics[mujoco-py]) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/strider/.local/lib/python3.10/site-packages (from Jinja2>=3.0.3->gymnasium-robotics[mujoco-py]) (2.1.3)
# Requirement already satisfied: absl-py in /home/strider/.local/lib/python3.10/site-packages (from mujoco>=2.3.3->gymnasium-robotics[mujoco-py]) (2.0.0)
# Requirement already satisfied: glfw in /home/strider/.local/lib/python3.10/site-packages (from mujoco>=2.3.3->gymnasium-robotics[mujoco-py]) (2.6.2)
# Requirement already satisfied: pyopengl in /usr/lib/python3/dist-packages (from mujoco>=2.3.3->gymnasium-robotics[mujoco-py]) (3.1.5)
# Requirement already satisfied: pillow>=8.3.2 in /usr/lib/python3/dist-packages (from imageio->gymnasium-robotics[mujoco-py]) (9.0.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load Environment

# %%
environment_name = "FetchReachDense-v2"

# %%
# Creates an environment previously registered with gymnasium.register() or a EnvSpec.
env = gym.make(environment_name)
#gym.make??

# %%
# Resets the environment to the initial state, required before calling step. 
# Returns the first agent observation for an episode and information, i.e. metrics, debug info.
env.reset()
# Out:
# ({'observation': array([ 1.34185486e+00,  7.49100508e-01,  5.34707205e-01,  2.00232294e-04,
#           6.92377335e-05, -3.25336729e-06, -2.19655130e-09,  5.16581247e-06,
#           4.76882452e-06, -2.31810359e-06]),
#   'achieved_goal': array([1.34185486, 0.74910051, 0.5347072 ]),
#   'desired_goal': array([1.37528771, 0.71790258, 0.60663199])},
#  {})

# %%
# This method defines how many discrete/actions there are. 
# The Space object corresponding to valid actions, all valid actions should be contained within the space.
env.action_space
# Out:
# Box(-1.0, 1.0, (4,), float32)

# %%
# This is the method that allows you to view the observation space
env.observation_space
# Out:
# OrderedDict([('achieved_goal', array([-0.80570279,  0.33007362, -0.85485567])),
#              ('desired_goal', array([ 0.17337401, -1.25829022,  0.22100899])),
#              ('observation',
#               array([ 0.41221713, -0.71711916,  1.26236457,  0.65946385,  1.28486468,
#                       0.81318092,  1.0118798 ,  0.73813479, -0.97106976,  1.02243229]))])

# %% [markdown]
# ### Run for loop of environment

# %%
# Closes the environment, which is important when external software is used, i.e. pygame for rendering, databases
env.close()

# %%
env = gym.make(environment_name,render_mode="human") # `render_mode` allows the environment to ve visualized.

# %%
# Create a loop to test our the reach environment
episodes = 3
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info, __ = env.step(action)
        score+=reward
        # print(score)
        if score < -100:
            break
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-100.15069724624391
# Episode:2 Score:-100.08685220842337
# Episode:3 Score:-100.07345328470538

# %% [markdown]
# # Understanding The Environment
# https://robotics.farama.org/envs/fetch/reach/

# %%
# The action space is a Box(-1.0, 1.0, (4,), float32). An action represents the Cartesian displacement dx, dy, and dz 
# of the end effector. In addition to a last action that controls closing and opening of the gripper. This last action 
# is not required since there is no object to be manipulated, thus its value won’t generate any control output.
env.action_space.sample()
# Out:
# array([ 0.82578987, -0.4887287 ,  0.81608254, -0.30251455], dtype=float32)

# %%
# The observation is a goal-aware observation space. It consists of a dictionary with information about the robot’s end 
# effector state and goal. 
env.observation_space.sample()
# Out:
# OrderedDict([('achieved_goal', array([ 0.32617484, -0.17370267, -1.25221234])),
#              ('desired_goal', array([-1.1180499 ,  0.77907649,  0.83331702])),
#              ('observation',
#               array([ 0.93202486, -0.51681035, -0.10157951, -1.14686444,  0.32856169,
#                      -1.01855906,  0.36187152, -1.14371704,  0.27138729, -0.22074443]))])

# %% [markdown]
# # 3. Train an RL Model

# %%
# Make your directories first
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MultiInputPolicy', env, verbose = 1, tensorboard_log=log_path)
# PPO??
# Out:
# Using cpu device

# %%
# Train your model, defining the total time steps. 
model.learn(total_timesteps=200000)
# Out:
# Logging to Training/Logs/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 398  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010254806 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0492      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.951       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009410427 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0168      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.938       |
# |    value_loss           | 0.0972      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016123941 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.031       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.925       |
# |    value_loss           | 0.0624      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020356525 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0219      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00971    |
# |    std                  | 0.916       |
# |    value_loss           | 0.0564      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 6           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020700216 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.909       |
# |    value_loss           | 0.0567      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 7           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010881079 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0131      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00871    |
# |    std                  | 0.899       |
# |    value_loss           | 0.0554      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 332        |
# |    iterations           | 8          |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01259071 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.22      |
# |    explained_variance   | 0.533      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0113     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00587   |
# |    std                  | 0.887      |
# |    value_loss           | 0.0445     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 9           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010641657 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0236      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00641    |
# |    std                  | 0.879       |
# |    value_loss           | 0.0401      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 10          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010021215 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0173     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00693    |
# |    std                  | 0.866       |
# |    value_loss           | 0.0349      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 11          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.025429446 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.07       |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0313     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.858       |
# |    value_loss           | 0.0322      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 12           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0144071635 |
# |    clip_fraction        | 0.171        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.04        |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0419       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 8.85e-05     |
# |    std                  | 0.851        |
# |    value_loss           | 0.0328       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 13          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012571815 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5          |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.044       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00543    |
# |    std                  | 0.843       |
# |    value_loss           | 0.0254      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 14          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018941958 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.95       |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00779    |
# |    std                  | 0.831       |
# |    value_loss           | 0.026       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 15          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016905151 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.9        |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00375    |
# |    std                  | 0.822       |
# |    value_loss           | 0.0242      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 16          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020770503 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.86       |
# |    explained_variance   | 0.781       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00431     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00449    |
# |    std                  | 0.816       |
# |    value_loss           | 0.0213      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 17          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012916827 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00604     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00383    |
# |    std                  | 0.813       |
# |    value_loss           | 0.0214      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 18          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.028127838 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000154    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0024      |
# |    std                  | 0.805       |
# |    value_loss           | 0.0171      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 322        |
# |    iterations           | 19         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01914668 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.78      |
# |    explained_variance   | 0.755      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00759    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.000604  |
# |    std                  | 0.802      |
# |    value_loss           | 0.015      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 20          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.029930994 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.73       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00262    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00102    |
# |    std                  | 0.79        |
# |    value_loss           | 0.0151      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 318        |
# |    iterations           | 21         |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02271512 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.68      |
# |    explained_variance   | 0.708      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00505   |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00228   |
# |    std                  | 0.783      |
# |    value_loss           | 0.0124     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 316        |
# |    iterations           | 22         |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02093667 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.65      |
# |    explained_variance   | 0.776      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00996   |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00137   |
# |    std                  | 0.777      |
# |    value_loss           | 0.00973    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 23          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025107402 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0069     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00329    |
# |    std                  | 0.768       |
# |    value_loss           | 0.0103      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 24          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022036918 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0148      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00592     |
# |    std                  | 0.758       |
# |    value_loss           | 0.00832     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 25          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.028370762 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00702     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 0.747       |
# |    value_loss           | 0.00908     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 310         |
# |    iterations           | 26          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.022862598 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000866    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0086      |
# |    std                  | 0.734       |
# |    value_loss           | 0.00716     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 309         |
# |    iterations           | 27          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.022868387 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0281     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00551     |
# |    std                  | 0.726       |
# |    value_loss           | 0.00649     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 28          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.035053022 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0319     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00713     |
# |    std                  | 0.714       |
# |    value_loss           | 0.00638     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 29          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.026361445 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0338      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00785     |
# |    std                  | 0.706       |
# |    value_loss           | 0.00479     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 30          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.026483804 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00109     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.009       |
# |    std                  | 0.694       |
# |    value_loss           | 0.0056      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 31          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.028947167 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0277      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0158      |
# |    std                  | 0.685       |
# |    value_loss           | 0.0046      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 32          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.020161891 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000903   |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00779     |
# |    std                  | 0.675       |
# |    value_loss           | 0.00371     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 305        |
# |    iterations           | 33         |
# |    time_elapsed         | 221        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.02336207 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.97      |
# |    explained_variance   | 0.668      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -6.98e-05  |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.0104     |
# |    std                  | 0.66       |
# |    value_loss           | 0.00329    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 34          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.028293096 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0231      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0148      |
# |    std                  | 0.649       |
# |    value_loss           | 0.00371     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 304        |
# |    iterations           | 35         |
# |    time_elapsed         | 235        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02399414 |
# |    clip_fraction        | 0.37       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.82      |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00605   |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.0114     |
# |    std                  | 0.642      |
# |    value_loss           | 0.00312    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 36          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.034399904 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0323     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00618     |
# |    std                  | 0.629       |
# |    value_loss           | 0.00281     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 37          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.023941342 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00705     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0071      |
# |    std                  | 0.62        |
# |    value_loss           | 0.00261     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 38          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.030599404 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0251      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 0.607       |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 39          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.040496055 |
# |    clip_fraction        | 0.381       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0112      |
# |    std                  | 0.597       |
# |    value_loss           | 0.00203     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 40          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.054684877 |
# |    clip_fraction        | 0.393       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0234      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.0144      |
# |    std                  | 0.591       |
# |    value_loss           | 0.00435     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 41          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.044977177 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0203      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00253     |
# |    std                  | 0.58        |
# |    value_loss           | 0.00219     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 42         |
# |    time_elapsed         | 285        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.06176395 |
# |    clip_fraction        | 0.448      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.28      |
# |    explained_variance   | 0.689      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0291     |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.0141     |
# |    std                  | 0.572      |
# |    value_loss           | 0.00206    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 43         |
# |    time_elapsed         | 292        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.03723854 |
# |    clip_fraction        | 0.397      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.575      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0202     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0141     |
# |    std                  | 0.563      |
# |    value_loss           | 0.00227    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 300        |
# |    iterations           | 44         |
# |    time_elapsed         | 299        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.03635151 |
# |    clip_fraction        | 0.417      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.13      |
# |    explained_variance   | 0.427      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0583     |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0165     |
# |    std                  | 0.553      |
# |    value_loss           | 0.0023     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 45          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.051818263 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0459     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.0149      |
# |    std                  | 0.55        |
# |    value_loss           | 0.00236     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 46          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.049085133 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00228     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.0184      |
# |    std                  | 0.548       |
# |    value_loss           | 0.0025      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 47          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.042716123 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.0126      |
# |    std                  | 0.539       |
# |    value_loss           | 0.00171     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 48          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.039998822 |
# |    clip_fraction        | 0.423       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0784      |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.0149      |
# |    std                  | 0.532       |
# |    value_loss           | 0.00188     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 299        |
# |    iterations           | 49         |
# |    time_elapsed         | 335        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.08795361 |
# |    clip_fraction        | 0.458      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.85      |
# |    explained_variance   | 0.558      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0254     |
# |    n_updates            | 580        |
# |    policy_gradient_loss | 0.0114     |
# |    std                  | 0.525      |
# |    value_loss           | 0.00168    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 299        |
# |    iterations           | 50         |
# |    time_elapsed         | 342        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.08157092 |
# |    clip_fraction        | 0.477      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.81      |
# |    explained_variance   | 0.44       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.139      |
# |    n_updates            | 590        |
# |    policy_gradient_loss | 0.0215     |
# |    std                  | 0.524      |
# |    value_loss           | 0.0024     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 51          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.058581997 |
# |    clip_fraction        | 0.479       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00128     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.0175      |
# |    std                  | 0.517       |
# |    value_loss           | 0.00154     |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 298      |
# |    iterations           | 52       |
# |    time_elapsed         | 356      |
# |    total_timesteps      | 106496   |
# | train/                  |          |
# |    approx_kl            | 0.07727  |
# |    clip_fraction        | 0.45     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.71    |
# |    explained_variance   | 0.466    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0795   |
# |    n_updates            | 610      |
# |    policy_gradient_loss | 0.0253   |
# |    std                  | 0.515    |
# |    value_loss           | 0.00294  |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 53          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.055445705 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.0195      |
# |    std                  | 0.51        |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 54          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.039178394 |
# |    clip_fraction        | 0.442       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0223      |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.0157      |
# |    std                  | 0.505       |
# |    value_loss           | 0.00188     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 298        |
# |    iterations           | 55         |
# |    time_elapsed         | 376        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.08097668 |
# |    clip_fraction        | 0.485      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.55      |
# |    explained_variance   | 0.589      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.107      |
# |    n_updates            | 640        |
# |    policy_gradient_loss | 0.0336     |
# |    std                  | 0.503      |
# |    value_loss           | 0.00148    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 298        |
# |    iterations           | 56         |
# |    time_elapsed         | 383        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.07147992 |
# |    clip_fraction        | 0.464      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.5       |
# |    explained_variance   | 0.594      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0117     |
# |    n_updates            | 650        |
# |    policy_gradient_loss | 0.0238     |
# |    std                  | 0.496      |
# |    value_loss           | 0.0014     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 57          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.035523586 |
# |    clip_fraction        | 0.522       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0283     |
# |    n_updates            | 660         |
# |    policy_gradient_loss | 0.0489      |
# |    std                  | 0.487       |
# |    value_loss           | 0.00175     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 58          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.064568706 |
# |    clip_fraction        | 0.482       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.145       |
# |    n_updates            | 670         |
# |    policy_gradient_loss | 0.0337      |
# |    std                  | 0.484       |
# |    value_loss           | 0.00326     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 59          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.058125712 |
# |    clip_fraction        | 0.522       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0207     |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.0426      |
# |    std                  | 0.477       |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 298       |
# |    iterations           | 60        |
# |    time_elapsed         | 412       |
# |    total_timesteps      | 122880    |
# | train/                  |           |
# |    approx_kl            | 0.0748364 |
# |    clip_fraction        | 0.477     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.23     |
# |    explained_variance   | 0.696     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.127     |
# |    n_updates            | 690       |
# |    policy_gradient_loss | 0.0408    |
# |    std                  | 0.47      |
# |    value_loss           | 0.00181   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 61          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.075853124 |
# |    clip_fraction        | 0.481       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0243     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | 0.0286      |
# |    std                  | 0.463       |
# |    value_loss           | 0.00267     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 297        |
# |    iterations           | 62         |
# ...
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00905   |
# |    n_updates            | 870        |
# |    policy_gradient_loss | 0.0282     |
# |    std                  | 0.423      |
# |    value_loss           | 0.00194    |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 295       |
# |    iterations           | 79        |
# |    time_elapsed         | 547       |
# |    total_timesteps      | 161792    |
# | train/                  |           |
# |    approx_kl            | 0.0513594 |
# |    clip_fraction        | 0.589     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.44     |
# |    explained_variance   | 0.923     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000925  |
# |    n_updates            | 880       |
# |    policy_gradient_loss | 0.0374    |
# |    std                  | 0.418     |
# |    value_loss           | 0.00179   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 80          |
# |    time_elapsed         | 554         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.067684166 |
# |    clip_fraction        | 0.595       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | 0.0542      |
# |    std                  | 0.413       |
# |    value_loss           | 0.0023      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 81         |
# |    time_elapsed         | 561        |
# |    total_timesteps      | 165888     |
# | train/                  |            |
# |    approx_kl            | 0.19213098 |
# |    clip_fraction        | 0.571      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.108      |
# |    n_updates            | 900        |
# |    policy_gradient_loss | 0.0519     |
# |    std                  | 0.415      |
# |    value_loss           | 0.00465    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 82         |
# |    time_elapsed         | 568        |
# |    total_timesteps      | 167936     |
# | train/                  |            |
# |    approx_kl            | 0.09546271 |
# |    clip_fraction        | 0.518      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0115     |
# |    n_updates            | 910        |
# |    policy_gradient_loss | 0.0367     |
# |    std                  | 0.411      |
# |    value_loss           | 0.0028     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 83         |
# |    time_elapsed         | 575        |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.08444151 |
# |    clip_fraction        | 0.512      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0105    |
# |    n_updates            | 920        |
# |    policy_gradient_loss | 0.0261     |
# |    std                  | 0.411      |
# |    value_loss           | 0.0029     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 84          |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.083131775 |
# |    clip_fraction        | 0.538       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0154      |
# |    n_updates            | 930         |
# |    policy_gradient_loss | 0.0334      |
# |    std                  | 0.413       |
# |    value_loss           | 0.00356     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 85          |
# |    time_elapsed         | 589         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.082471974 |
# |    clip_fraction        | 0.572       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0748      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | 0.0384      |
# |    std                  | 0.412       |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 86          |
# |    time_elapsed         | 596         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.064968474 |
# |    clip_fraction        | 0.542       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.0292      |
# |    std                  | 0.406       |
# |    value_loss           | 0.00262     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 87         |
# |    time_elapsed         | 603        |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.08891484 |
# |    clip_fraction        | 0.528      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.125      |
# |    n_updates            | 960        |
# |    policy_gradient_loss | 0.0442     |
# |    std                  | 0.402      |
# |    value_loss           | 0.00229    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 88         |
# |    time_elapsed         | 610        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.15382017 |
# |    clip_fraction        | 0.505      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.106      |
# |    n_updates            | 970        |
# |    policy_gradient_loss | 0.0353     |
# |    std                  | 0.399      |
# |    value_loss           | 0.00272    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 89          |
# |    time_elapsed         | 617         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.068387255 |
# |    clip_fraction        | 0.524       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 980         |
# |    policy_gradient_loss | 0.0275      |
# |    std                  | 0.398       |
# |    value_loss           | 0.00133     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 90          |
# |    time_elapsed         | 624         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.085144304 |
# |    clip_fraction        | 0.502       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0625      |
# |    n_updates            | 990         |
# |    policy_gradient_loss | 0.0247      |
# |    std                  | 0.396       |
# |    value_loss           | 0.0023      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 91         |
# |    time_elapsed         | 631        |
# |    total_timesteps      | 186368     |
# | train/                  |            |
# |    approx_kl            | 0.10294477 |
# |    clip_fraction        | 0.598      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0159     |
# |    n_updates            | 1000       |
# |    policy_gradient_loss | 0.0577     |
# |    std                  | 0.391      |
# |    value_loss           | 0.00279    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 294        |
# |    iterations           | 92         |
# |    time_elapsed         | 638        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.10767022 |
# |    clip_fraction        | 0.579      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0148    |
# |    n_updates            | 1010       |
# |    policy_gradient_loss | 0.0391     |
# |    std                  | 0.391      |
# |    value_loss           | 0.00189    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 294        |
# |    iterations           | 93         |
# |    time_elapsed         | 646        |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.09277184 |
# |    clip_fraction        | 0.59       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0138     |
# |    n_updates            | 1020       |
# |    policy_gradient_loss | 0.0303     |
# |    std                  | 0.387      |
# |    value_loss           | 0.00143    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 94          |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.054123275 |
# |    clip_fraction        | 0.609       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0373      |
# |    n_updates            | 1030        |
# |    policy_gradient_loss | 0.0574      |
# |    std                  | 0.392       |
# |    value_loss           | 0.00345     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 95          |
# |    time_elapsed         | 661         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.074223585 |
# |    clip_fraction        | 0.564       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.037       |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | 0.0344      |
# |    std                  | 0.389       |
# |    value_loss           | 0.00213     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 96         |
# |    time_elapsed         | 669        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.12234089 |
# |    clip_fraction        | 0.556      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.125      |
# |    n_updates            | 1050       |
# |    policy_gradient_loss | 0.0464     |
# |    std                  | 0.391      |
# |    value_loss           | 0.00464    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 97         |
# |    time_elapsed         | 676        |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.11907582 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.993     |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.143      |
# |    n_updates            | 1060       |
# |    policy_gradient_loss | 0.0472     |
# |    std                  | 0.389      |
# |    value_loss           | 0.00337    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 98         |
# |    time_elapsed         | 684        |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.13012166 |
# |    clip_fraction        | 0.587      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.965     |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.135      |
# |    n_updates            | 1070       |
# |    policy_gradient_loss | 0.0688     |
# |    std                  | 0.387      |
# |    value_loss           | 0.00145    |
# ----------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_Fetch_Reach_model')

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load(PPO_path, env=env)

# %% [markdown]
# # 4. Evaluation

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make(environment_name,render_mode="human")
env = DummyVecEnv([lambda: env])
evaluate_policy(model, env, n_eval_episodes=6, render=True)
# Out:
# /home/strider/.local/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-6.876124573250611, 1.488251813926538)

# %%
env.close()

# %% [markdown]
# # 5. Test Model

# %%
env = gym.make(environment_name,render_mode="human")
env = DummyVecEnv([lambda: env])
episodes = 10
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action,  _state = model.predict(obs) #NOW USING MODEL HERE!!!
        obs, reward, done, info = env.step(action)
        score+=reward

    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:[-12.344315]
# /home/strider/.local/lib/python3.10/site-packages/glfw/__init__.py:916: GLFWError: (65544) b'Wayland: Standard cursor shape unavailable'
#   warnings.warn(message, GLFWError)
# Episode:2 Score:[-13.3492985]
# Episode:3 Score:[-7.520219]
# Episode:4 Score:[-8.934184]
# Episode:5 Score:[-14.073304]
# Episode:6 Score:[-10.518241]
# Episode:7 Score:[-13.509146]
# Episode:8 Score:[-6.328489]
# Episode:9 Score:[-12.732246]
# Episode:10 Score:[-11.644218]

# %% [markdown]
# ### Reviewing the model methods

# %%
# model method api
model.predict??

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
obs = env.reset()

# %%
obs
# Out:
# array([[ 0.03617643, -0.01765439,  0.03399159, -0.02785905]],
#       dtype=float32)

# %%
action, _states = model.predict(obs)

# %%
env.step(action)
# Out:
# (array([[ 0.03582334,  0.17696403,  0.03343441, -0.30962643]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{'TimeLimit.truncated': False}])

# %% [markdown]
# # 6. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join('Training', 'Logs', 'PPO_1')
# training_log_path

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# TensorFlow installation not found - running with reduced feature set.
# /home/alan/.local/lib/python3.8/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.33' not found (required by /home/alan/.local/lib/python3.8/site-packages/tensorboard_data_server/bin/server)
# /home/alan/.local/lib/python3.8/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /home/alan/.local/lib/python3.8/site-packages/tensorboard_data_server/bin/server)
# /home/alan/.local/lib/python3.8/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.32' not found (required by /home/alan/.local/lib/python3.8/site-packages/tensorboard_data_server/bin/server)
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.14.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
